# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np

import os
import shutil

import re

# %%
def create_mask(image_path):
  try:
    image = cv2.imread(image_path)
    if image is None:
      print(f'failed to read image: {image_path}')
      return None

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    mask = np.zeros(image.shape[:2], dtype=np.uint8)

    cv2.drawContours(mask, contours, -1, 255, thickness=cv2.FILLED)

    return mask
  except Exception as e:
    print(f'error procesing {image_path}: {str(e)}')
    return None

# %%
def natural_sort_key(s):
    return [int(c) if c.isdigit() else c.lower() for c in re.split(r'(\d+)', s)]

# %%
# Dataset
base_dir = "/content/drive/MyDrive/Dataset"

# masks
output_base_dir = "/content/drive/MyDrive/mask"

# %%
# Create the main mask directory

if os.path.exists(output_base_dir):
    if os.path.isfile(output_base_dir):
        print(f"Error: {output_base_dir} is a file. Please specify a different path for the output directory.")
        exit(1)
    else:
        print(f"Warning: {output_base_dir} already exists. Existing contents will be overwritten.")
        shutil.rmtree(output_base_dir)
os.makedirs(output_base_dir)

# %%
# Get all subdirectories in the base directory
gestures = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

# %%
# Process each gesture
for gesture in gestures:
    input_dir = os.path.join(base_dir, gesture)
    output_dir = os.path.join(output_base_dir, f"mask_{gesture}")

    # Create the gesture-specific mask directory
    os.makedirs(output_dir, exist_ok=True)

    # Get all image files in the gesture directory and sort them
    image_files = [f for f in os.listdir(input_dir) if f.lower().endswith((".jpg", ".png", ".jpeg"))]
    image_files.sort(key=natural_sort_key)  # Use natural sorting

    # Process all images in the gesture directory
    for filename in image_files:
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, f"mask_{filename}")

        # Create and save the mask
        mask = create_mask(input_path)
        if mask is not None:
            cv2.imwrite(output_path, mask)
            print(f"Processed: {gesture}/{filename}")
        else:
            print(f"Failed to process: {gesture}/{filename}")

print("Mask creation completed.")
# Out:
# Processed: Fist/Fist_1.jpg.jpg
# Processed: Fist/Fist_2.jpg.jpg
# Processed: Fist/Fist_3.jpg.jpg
# Processed: Fist/Fist_4.jpg.jpg
# Processed: Fist/Fist_5.jpg.jpg
# Processed: Fist/Fist_6.jpg.jpg
# Processed: Fist/Fist_7.jpg.jpg
# Processed: Fist/Fist_8.jpg.jpg
# Processed: Fist/Fist_9.jpg.jpg
# Processed: Fist/Fist_10.jpg.jpg
# Processed: Fist/Fist_11.jpg.jpg
# Processed: Fist/Fist_12.jpg.jpg
# Processed: Fist/Fist_13.jpg.jpg
# Processed: Fist/Fist_14.jpg.jpg
# Processed: Fist/Fist_15.jpg.jpg
# Processed: Fist/Fist_16.jpg.jpg
# Processed: Fist/Fist_17.jpg.jpg
# Processed: Fist/Fist_18.jpg.jpg
# Processed: Fist/Fist_19.jpg.jpg
# Processed: Fist/Fist_20.jpg.jpg
# Processed: Fist/Fist_21.jpg.jpg
# Processed: Fist/Fist_22.jpg.jpg
# Processed: Fist/Fist_23.jpg.jpg
# Processed: Fist/Fist_24.jpg.jpg
# Processed: Fist/Fist_25.jpg.jpg
# Processed: Fist/Fist_26.jpg.jpg
# Processed: Fist/Fist_27.jpg.jpg
# Processed: Fist/Fist_28.jpg.jpg
# Processed: Fist/Fist_29.jpg.jpg
# Processed: Fist/Fist_30.jpg.jpg
# Processed: Fist/Fist_31.jpg.jpg
# Processed: Fist/Fist_32.jpg.jpg
# Processed: Fist/Fist_33.jpg.jpg
# Processed: Fist/Fist_34.jpg.jpg
# Processed: Fist/Fist_35.jpg.jpg
# Processed: Fist/Fist_36.jpg.jpg
# Processed: PeaceSign/PeaceSign_42.jpg.jpg
# Processed: PeaceSign/PeaceSign_43.jpg.jpg
# Processed: PeaceSign/PeaceSign_44.jpg.jpg
# Processed: PeaceSign/PeaceSign_45.jpg.jpg
# Processed: PeaceSign/PeaceSign_46.jpg.jpg
# Processed: PeaceSign/PeaceSign_47.jpg.jpg
# Processed: PeaceSign/PeaceSign_48.jpg.jpg
# Processed: PeaceSign/PeaceSign_49.jpg.jpg
# Processed: PeaceSign/PeaceSign_50.jpg.jpg
# Processed: OpenPalm/OpenPalm_1.jpg.jpg
# Processed: OpenPalm/OpenPalm_2.jpg.jpg
# Processed: OpenPalm/OpenPalm_3.jpg.jpg
# Processed: OpenPalm/OpenPalm_4.jpg.jpg
# Processed: OpenPalm/OpenPalm_5.jpg.jpg
# Processed: OpenPalm/OpenPalm_6.jpg.jpg
# Processed: OpenPalm/OpenPalm_7.jpg.jpg
# Processed: OpenPalm/OpenPalm_8.jpg.jpg
# Processed: OpenPalm/OpenPalm_9.jpg.jpg
# Processed: OpenPalm/OpenPalm_10.jpg.jpg
# Processed: OpenPalm/OpenPalm_11.jpg.jpg
# Processed: OpenPalm/OpenPalm_12.jpg.jpg
# Processed: OpenPalm/OpenPalm_13.jpg.jpg
# Processed: OpenPalm/OpenPalm_14.jpg.jpg
# Processed: OpenPalm/OpenPalm_15.jpg.jpg
# Processed: OpenPalm/OpenPalm_16.jpg.jpg
# Processed: OpenPalm/OpenPalm_17.jpg.jpg
# Processed: OpenPalm/OpenPalm_18.jpg.jpg
# Processed: OpenPalm/OpenPalm_19.jpg.jpg
# Processed: OpenPalm/OpenPalm_20.jpg.jpg
# Processed: OpenPalm/OpenPalm_21.jpg.jpg
# Processed: OpenPalm/OpenPalm_22.jpg.jpg
# Processed: OpenPalm/OpenPalm_23.jpg.jpg
# Processed: OpenPalm/OpenPalm_24.jpg.jpg
# Processed: OpenPalm/OpenPalm_25.jpg.jpg
# Processed: OpenPalm/OpenPalm_26.jpg.jpg
# Processed: OpenPalm/OpenPalm_27.jpg.jpg
# Processed: OpenPalm/OpenPalm_28.jpg.jpg
# Processed: OpenPalm/OpenPalm_29.jpg.jpg
# Processed: OpenPalm/OpenPalm_30.jpg.jpg
# Processed: OpenPalm/OpenPalm_31.jpg.jpg
# Processed: OpenPalm/OpenPalm_32.jpg.jpg
# Processed: OpenPalm/OpenPalm_33.jpg.jpg
# Processed: OpenPalm/OpenPalm_34.jpg.jpg
# Processed: OpenPalm/OpenPalm_35.jpg.jpg
# Processed: OpenPalm/OpenPalm_36.jpg.jpg
# Processed: OpenPalm/OpenPalm_37.jpg.jpg
# Processed: OpenPalm/OpenPalm_38.jpg.jpg
# Processed: OpenPalm/OpenPalm_39.jpg.jpg
# Processed: OpenPalm/OpenPalm_40.jpg.jpg
# Processed: OpenPalm/OpenPalm_41.jpg.jpg
# Processed: OpenPalm/OpenPalm_42.jpg.jpg
# Processed: OpenPalm/OpenPalm_43.jpg.jpg
# Processed: OpenPalm/OpenPalm_44.jpg.jpg
# Processed: OpenPalm/OpenPalm_45.jpg.jpg
# Processed: OpenPalm/OpenPalm_46.jpg.jpg
# Processed: OpenPalm/OpenPalm_47.jpg.jpg
# Processed: OpenPalm/OpenPalm_48.jpg.jpg
# Processed: OpenPalm/OpenPalm_49.jpg.jpg
# Processed: OpenPalm/OpenPalm_50.jpg.jpg
# Mask creation completed.
